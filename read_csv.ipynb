# %%
import pandas as pd

# %%
df = pd.read_csv("mypub.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-16-6ac71895be21> in <module>
# ----> 1 df = pd.read_csv("mypub.csv")
#
# /usr/local/lib64/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
# ...

# %%
df.columns
# Out:
# Index(['texkeys', ' arxiv_eprints', ' preprint_date', ' citation_count',
#        ' citation_count_without_self_citations', ' doi', ' title'],
#       dtype='object')

# %%
df[[]]
# Out:
#                 texkeys   arxiv_eprints  preprint_date   citation_count  \
# 0           Fox:2020hfm      2012.04533     2020-12-08                0
# 1           Aad:2020fpj      2009.14791     2020-09-30                6
# 2            Ju:2020tbo      2008.06064     2020-08-25                6
# 3           Aad:2020xfq      2007.07830     2020-07-15               34
# 4         Choma:2020cry      2007.00149     2020-06-30                2
# 5           Aad:2020ivc      2004.04545     2020-04-09               21
# 6            Ju:2020xty      2003.11603     2020-03-25               18
# 7        Aaboud:2018bun      1808.02380     2018-08-07               79
# 8        Aaboud:2017rel      1712.06386     2017-12-18              105
# 9        Aaboud:2017phn      1711.03301     2017-11-09              284
# 10       Aaboud:2017itg      1708.09638     2017-08-31               90
# 11       Aaboud:2017yyg      1707.04147     2017-07-13              156
# ...
